# %% [markdown]
# <a href="https://colab.research.google.com/github/elhamod/IS883_Azure_OpenAI_demo/blob/main/IS883_streamlit_OpenAI_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Run a streamlit app from a Google Colab Notebook
# > Adopted from a notebook by [Manuel Romero](https://twitter.com/mrm8488)
#
# This notebook will help you try changes to your code before deploying it to Azue.

# %%
# !pip install -q streamlit
# !pip install openai
# !npm install localtunnel
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 0.552s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %% [markdown]
# ##Fetch OpenAI API key

# %%
# %%capture

from google.colab import drive
drive.mount('/content/drive/')

import os

config_ini_location = '/content/drive/MyDrive/Class/IS883DigitalEfforts/config.ini'

import configparser

config = configparser.ConfigParser()
config.read(config_ini_location)
openai_api_key = config['OpenAI']['API_KEY']


os.environ.setdefault('OPENAI_API_KEY', openai_api_key)

# %% [markdown]
# ## Run streamlit in background
#
# It will run the contents of `azure.py` and show an IP address.

# %%
# !streamlit run "/content/drive/MyDrive/Class/IS883DigitalEfforts/Streamlit/IS883_Azure_OpenAI_demo/resources/azure.py" &>/content/logs.txt & curl ipv4.icanhazip.com
# Out:
# 35.203.159.218

# %% [markdown]
# ## Expose the port 8501
# Then just click in the `url` shown below and enter the IP address generated.

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 2.195s
# your url is: https://better-coins-search.loca.lt
# /root/.npm/_npx/5267/lib/node_modules/localtunnel/bin/lt.js:81
#     throw err;
#     ^
#
# Error: connection refused: localtunnel.me:40205 (check your firewall settings)
#     at Socket.<anonymous> (/root/.npm/_npx/5267/lib/node_modules/localtunnel/lib/TunnelCluster.js:52:11)
#     at Socket.emit (events.js:315:20)
#     at emitErrorNT (internal/streams/destroy.js:106:8)
#     at emitErrorCloseNT (internal/streams/destroy.js:74:3)
#     at processTicksAndRejections (internal/process/task_queues.js:80:21)

# %% [markdown]
# [![ko-fi](https://www.ko-fi.com/img/githubbutton_sm.svg)](https://ko-fi.com/Y8Y3VYYE)
